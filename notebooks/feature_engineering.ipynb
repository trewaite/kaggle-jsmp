# %%
import sys
import os
import csv
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook as tqdm
from copy import deepcopy

from sklearn.decomposition import PCA

#metrics
from sklearn.metrics import roc_auc_score, accuracy_score

sns.set_style('darkgrid')
pd.set_option('display.float_format', lambda x: '%.3f' % x)

SEED = 26
np.random.seed(SEED)

# %% [markdown]
# ### Read In Data

# %%
# %%time
dtype_dict = {}
for f in range(0,130):
    dtype_dict[f'feature_{f}'] = 'float32'
train = pd.read_csv('../inputs/train.csv')
# Out:
# CPU times: user 1min 16s, sys: 6.29 s, total: 1min 23s
# Wall time: 2min 59s

# %%
# %%time
train_fold_ind = pd.read_csv('../preprocessed/train_fold_ind.csv')
# Out:
# CPU times: user 701 ms, sys: 8.18 ms, total: 709 ms
# Wall time: 1.35 s

# %%
df = pd.concat([train,train_fold_ind[['fold']]],axis=1)
del train

# %%
df.head()
# Out:
#    date  weight  resp_1  resp_2  resp_3  resp_4   resp  feature_0  feature_1  \
# 0     0   0.000   0.010   0.014   0.009   0.001  0.006          1     -1.873
# 1     0  16.674  -0.003  -0.003  -0.007  -0.011 -0.010         -1     -1.350
# 2     0   0.000   0.025   0.028   0.033   0.034  0.024         -1      0.813
# 3     0   0.000  -0.005  -0.003  -0.000  -0.000 -0.003         -1      1.174
# 4     0   0.139   0.001   0.002  -0.001  -0.006 -0.003          1     -3.172
#
#    feature_2  ...  feature_122  feature_123  feature_124  feature_125  \
# 0     -2.191  ...        1.168        8.314        1.782       14.018
# 1     -1.705  ...       -1.179        1.777       -0.915        2.832
# 2     -0.256  ...        6.116        9.668        5.543       11.672
# 3      0.345  ...        2.839        0.499        3.034        1.513
# 4     -3.093  ...        0.345        4.101        0.614        6.623
#
#    feature_126  feature_127  feature_128  feature_129  ts_id        fold
# 0        2.653       12.600        2.301       11.446      0  train_fold
# 1       -1.417        2.297       -1.305        1.899      1  train_fold
# 2        7.282       10.060        6.638        9.427      2  train_fold
# 3        4.398        1.266        3.856        1.013      3  train_fold
# 4        0.800        5.233        0.363        3.927      4  train_fold
#
# [5 rows x 139 columns]

# %% [markdown]
# ### Create Features

# %%
original_features = [f"feature_{f}" for f in range(0,130)]

# %%
def create_daily_return_lags(df, lags):
    df_daily = df[['date','resp']].groupby(['date']).mean().reset_index()
    
    print("Creating daily lag features...")
    for lag in tqdm(lags):
        col_name = '_'.join(['resp_daily_lag',str(lag)])
        df_daily[col_name] = df_daily['resp'].shift(lag)
        
    df = pd.merge(df, df_daily, on=['date'], how='left')
    
    return df

# %%
# %%time
df = create_daily_return_lags(df, lags=[1,2,3,4,5,6,7])
# Out:
# Creating daily lag features...
# <ipython-input-7-b35438b8423b>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for lag in tqdm(lags):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7.0), HTML(value='')))
# CPU times: user 11.2 s, sys: 10.3 s, total: 21.6 s
# Wall time: 22.2 s

# %%
df.tail()
# Out:
#          date  weight  resp_1  resp_2  resp_3  resp_4  resp_x  feature_0  \
# 2390486   499   0.000   0.000   0.000   0.006   0.020   0.015          1
# 2390487   499   0.000   0.000   0.000  -0.001  -0.006  -0.005          1
# 2390488   499   0.000   0.000   0.000   0.008   0.025   0.017          1
# 2390489   499   0.283  -0.000  -0.000  -0.001  -0.004  -0.002         -1
# 2390490   499   0.000  -0.002  -0.002  -0.001  -0.001  -0.002         -1
#
#          feature_1  feature_2  ...    ts_id    fold  resp_y  resp_daily_lag_1  \
# 2390486     -1.649     -1.170  ...  2390486  fold_4   0.000             0.002
# 2390487      2.433      5.285  ...  2390487  fold_4   0.000             0.002
# 2390488     -0.622     -0.964  ...  2390488  fold_4   0.000             0.002
# 2390489     -1.464     -1.107  ...  2390489  fold_4   0.000             0.002
# 2390490     -1.817     -1.132  ...  2390490  fold_4   0.000             0.002
#
#          resp_daily_lag_2  resp_daily_lag_3  resp_daily_lag_4  \
# 2390486             0.003             0.001             0.002
# 2390487             0.003             0.001             0.002
# 2390488             0.003             0.001             0.002
# 2390489             0.003             0.001             0.002
# 2390490             0.003             0.001             0.002
#
#          resp_daily_lag_5  resp_daily_lag_6  resp_daily_lag_7
# 2390486             0.001            -0.001            -0.002
# 2390487             0.001            -0.001            -0.002
# 2390488             0.001            -0.001            -0.002
# 2390489             0.001            -0.001            -0.002
# 2390490             0.001            -0.001            -0.002
#
# [5 rows x 147 columns]

# %%
def find_null_features(df, threshold, fill_val):
    
    return columns

def find_top_corr_features(df, target, threshold):
    
    return columns

def find_top_skew_features():
    return columns

def create_day_features():
    '''
    create day of week features assuming starting monday and 5 day trading week
    '''
    return df
